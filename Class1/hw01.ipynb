# %% [markdown]
# homework01

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 500)

# %%
df=pd.read_csv('state.csv')
df
# Out:
#              State  Population  Murder.Rate Abbreviation
# 0          Alabama     4779736          5.7           AL
# 1           Alaska      710231          5.6           AK
# 2          Arizona     6392017          4.7           AZ
# 3         Arkansas     2915918          5.6           AR
# 4       California    37253956          4.4           CA
# 5         Colorado     5029196          2.8           CO
# 6      Connecticut     3574097          2.4           CT
# 7         Delaware      897934          5.8           DE
# 8          Florida    18801310          5.8           FL
# 9          Georgia     9687653          5.7           GA
# 10          Hawaii     1360301          1.8           HI
# 11           Idaho     1567582          2.0           ID
# 12        Illinois    12830632          5.3           IL
# 13         Indiana     6483802          5.0           IN
# 14            Iowa     3046355          1.9           IA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         50 non-null     object
#  1   Population    50 non-null     int64
#  2   Murder.Rate   50 non-null     float64
#  3   Abbreviation  50 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.7+ KB

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
percent_missing
# Out:
# State           0.0
# Population      0.0
# Murder.Rate     0.0
# Abbreviation    0.0
# dtype: float64

# %%
df._get_numeric_data().describe()
# Out:
#          Population  Murder.Rate
# count  5.000000e+01    50.000000
# mean   6.162876e+06     4.066000
# std    6.848235e+06     1.915736
# min    5.636260e+05     0.900000
# 25%    1.833004e+06     2.425000
# 50%    4.436370e+06     4.000000
# 75%    6.680312e+06     5.550000
# max    3.725396e+07    10.300000

# %%
df._get_numeric_data().hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E94ED37A08>,
# ...
#       dtype=object)

# %%
print(df['State'].value_counts())
print(df['Abbreviation'].value_counts())
# Out:
# Oklahoma          1
# Virginia          1
# Montana           1
# Utah              1
# Georgia           1
# Texas             1
# Maine             1
# Kansas            1
# North Carolina    1
# Arizona           1
# Vermont           1
# North Dakota      1
# Tennessee         1
# New Jersey        1
# South Dakota      1
# Kentucky          1
# Connecticut       1
# Alabama           1
# New Mexico        1
# Wisconsin         1
# Nevada            1
# Oregon            1
# Missouri          1
# Louisiana         1
# Delaware          1
# Hawaii            1
# California        1
# Illinois          1
# Idaho             1
# Minnesota         1
# Alaska            1
# Iowa              1
# South Carolina    1
# Michigan          1
# Arkansas          1
# Wyoming           1
# Mississippi       1
# Massachusetts     1
# West Virginia     1
# Colorado          1
# Florida           1
# New Hampshire     1
# Pennsylvania      1
# Ohio              1
# Maryland          1
# ...

# %%
df['State'].value_counts().plot.bar(x='State')

# %%
df.sort_values(by='Population').plot.bar(x='State', y='Population')

# %%
df.sort_values(by='Population').plot.bar(x='Population', y='Murder.Rate')

# %% [markdown]
# Summary: The relationship between Population and Murder rate is not linear
